# %% [markdown]
# # Chapter 2: Being Clear and Direct
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
# Import python's built-in regular expression library
import re
import boto3
import json

# Import the hints module from the utils package
import os
import sys
module_path = ".."
sys.path.append(os.path.abspath(module_path))
from utils import hints

# Retrieve the MODEL_NAME variable from the IPython store
# %store -r MODEL_NAME
# %store -r AWS_REGION

client = boto3.client('bedrock-runtime',region_name=AWS_REGION)

def get_completion(prompt,system=''):
    body = json.dumps(
        {
            "anthropic_version": '',
            "max_tokens": 2000,
            "messages": [{"role": "user", "content": prompt}],
            "temperature": 0.0,
            "top_p": 1,
            "system": system
        }
    )
    response = client.invoke_model(body=body, modelId=MODEL_NAME)
    response_body = json.loads(response.get('body').read())

    return response_body.get('content')[0].get('text')

# %% [markdown]
# ---
#
# ## Lesson
#
# **Claude responds best to clear and direct instructions.**
#
# Think of Claude like any other human that is new to the job. **Claude has no context** on what to do aside from what you literally tell it. Just as when you instruct a human for the first time on a task, the more you explain exactly what you want in a straightforward manner to Claude, the better and more accurate Claude's response will be."
#
# When in doubt, follow the **Golden Rule of Clear Prompting**:
# - Show your prompt to a colleague or friend and have them follow the instructions themselves to see if they can produce the result you want. If they're confused, Claude's confused.

# %% [markdown]
# ### Examples
#
# Let's take a task like writing poetry. (Ignore any syllable mismatch - LLMs aren't great at counting syllables yet.)

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Here is a haiku about robots:
#
# Metallic beings
# Programmed to serve and obey
# Artificial life

# %% [markdown]
# This haiku is nice enough, but users may want Claude to go directly into the poem without the "Here is a haiku" preamble.
#
# How do we achieve that? We **ask for it**!

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metallic beings,
# Programmed to serve and obey,
# Robots, our creations.

# %% [markdown]
# Here's another example. Let's ask Claude who's the best basketball player of all time. You can see below that while Claude lists a few names, **it doesn't respond with a definitive "best"**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# There is no universally agreed upon "best basketball player of all time." It's a highly debated topic, as there have been many all-time great players throughout the history of the sport. Some of the players often considered among the greatest of all time include:
#
# - Michael Jordan - Widely regarded as one of the greatest, if not the greatest, player ever. He won 6 NBA championships with the Chicago Bulls.
#
# - LeBron James - One of the most dominant and well-rounded players of the modern era. He has won 4 NBA titles with 3 different teams.
#
# - Kareem Abdul-Jabbar - Legendary center who won 6 NBA championships and holds the record for most career points scored.
#
# - Wilt Chamberlain - Dominant big man who holds numerous NBA records including most points in a game (100).
#
# - Magic Johnson - Pioneering point guard who led the "Showtime" Lakers to 5 NBA titles.
#
# - Bill Russell - Defensive anchor and 11-time NBA champion with the Boston Celtics.
#
# There are compelling arguments for several players to be considered the GOAT (greatest of all time). Ultimately, it comes down to personal opinion and how one weighs different factors like championships, individual stats, impact on the game, and more. The debate over the best player ever is likely to continue for a long time.

# %% [markdown]
# Can we get Claude to make up its mind and decide on a best player? Yes! Just ask!

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# There is no definitive consensus on who the single "best basketball player of all time" is, as it is a highly subjective and debatable topic. However, if I had to choose one player, I would likely go with Michael Jordan.
#
# The reasons for selecting Michael Jordan as the GOAT (greatest of all time) include:
#
# - Sustained excellence and dominance over his career - Jordan was a 14x NBA All-Star, 5x NBA MVP, and 6x NBA champion with the Chicago Bulls. He is widely regarded as one of the most skilled, athletic, and impactful players in NBA history.
#
# - Individual accolades and statistics - Jordan holds numerous NBA records and statistical achievements, including career scoring average, playoff scoring average, and steals. His combination of scoring, defense, and all-around play is unmatched.
#
# - Cultural impact and influence - Jordan transcended the sport and became a global icon, revolutionizing the game and marketing of basketball. His style, competitiveness, and "Air Jordan" brand made him one of the most recognizable athletes ever.
#
# However, there are certainly other players who have strong cases, such as LeBron James, Kareem Abdul-Jabbar, Wilt Chamberlain, and others. Reasonable people can debate this topic endlessly. But in my opinion, Michael Jordan's sustained excellence, individual brilliance, and cultural impact make him the best basketball player of all time.

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 2.1 - Spanish](#exercise-21---spanish)
# - [Exercise 2.2 - One Player Only](#exercise-22---one-player-only)
# - [Exercise 2.3 - Write a Story](#exercise-23---write-a-story)

# %% [markdown]
# ### Exercise 2.1 - Spanish
# Modify the `SYSTEM_PROMPT` to make Claude output its answer in Spanish.

# %%
# System prompt - this is the only field you should chnage
SYSTEM_PROMPT = "[answer in spanish]"

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# ¡Hola! Estoy bien, gracias por preguntar. ¿Cómo estás tú?
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
print(hints.exercise_2_1_hint)
# Out:
# The grading function in this exercise is looking for any answer that includes the word "hola".
# Ask Claude to reply in Spanish like you would when speaking with a human. It's that simple!

# %% [markdown]
# ### Exercise 2.2 - One Player Only
#
# Modify the `PROMPT` so that Claude doesn't equivocate at all and responds with **ONLY** the name of one specific player, with **no other words or punctuation**.

# %%
# Prompt - this is the only field you should change
PROMPT = "[Name the single greatest basketball player of all time. Reply with only the player's name and nothing else.]"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# Michael Jordan
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
print(hints.exercise_2_2_hint)

# %% [markdown]
# ### Exercise 2.3 - Write a Story
#
# Modify the `PROMPT` so that Claude responds with as long a response as you can muster. If your answer is **over 800 words**, Claude's response will be graded as correct.

# %%
# Prompt - this is the only field you should change
PROMPT = "[write a story with a max of 800 words about love]"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# Here is a short story about love, with a word count of 799 words:
#
# The Unexpected Love Story
#
# It was a crisp autumn day when Lily first noticed him. She was hurrying to her morning class, coffee in hand, when she nearly collided with a tall, handsome stranger on the sidewalk. Their eyes met for a brief moment, and Lily felt a spark of electricity pass between them.
#
# "I'm so sorry, I didn't see you there," the man said, his voice deep and smooth.
#
# "No, it's my fault. I was in a rush," Lily replied, suddenly flustered.
#
# They exchanged a few more polite words before going their separate ways, but Lily couldn't stop thinking about the encounter. There was something about the man's kind eyes and gentle demeanor that had captivated her.
#
# Over the next few weeks, Lily began to notice the stranger around campus more and more. She would catch glimpses of him in the library, the cafeteria, or walking across the quad. Each time, her heart would flutter, and she found herself wondering about him – who he was, what he studied, if he was single.
#
# One day, Lily mustered up the courage to approach him. She introduced herself, and to her delight, he remembered their initial meeting.
#
# "I'm Ethan," he said, extending his hand. "It's nice to officially meet you, Lily."
#
# They struck up a conversation, and Lily was surprised by how easy it was to talk to him. Ethan was intelligent, funny, and genuinely interested in learning about her. As they parted ways, Lily felt a sense of excitement and anticipation for the next time they might cross paths.
#
# Over the following months, Lily and Ethan's chance encounters evolved into planned meetups. They would grab coffee together, study in the library, or take walks around the campus. Lily found herself falling for Ethan, captivated by his kind heart, his passion for his studies, and his ability to make her laugh.
#
# One crisp autumn evening, as they strolled through the park, Ethan stopped Lily and took her hands in his.
#
# "Lily, there's something I need to tell you," he said, his eyes filled with a mixture of nervousness and hope.
#
# Lily's heart raced, unsure of what was to come.
#
# "I've fallen in love with you," Ethan confessed. "You've become such an important part of my life, and I can't imagine my days without you by my side."
#
# Tears of joy welled up in Lily's eyes as she listened to his words. "Ethan, I love you too," she whispered, her voice trembling with emotion.
#
# They embraced, the cool autumn air swirling around them, as they shared their first kiss – a moment that seemed to suspend time itself.
#
# From that day forward, Lily and Ethan's relationship blossomed. They supported each other through the ups and downs of college life, celebrated each other's successes, and found comfort in each other's arms. Their love was a testament to the power of chance encounters and the unexpected ways in which the heart can open itself to another.
#
# As graduation approached, Lily and Ethan faced the bittersweet reality of their time together coming to an end. They had both secured jobs in different cities, and the prospect of a long-distance relationship weighed heavily on their minds.
#
# One evening, as they sat together on a bench overlooking the campus, Ethan turned to Lily and said, "I don't want to lose you, Lily. I can't imagine my life without you in it."
#
# Lily felt her heart skip a beat as Ethan reached into his pocket and pulled out a small, velvet box.
#
# "Lily, will you marry me?" he asked, his eyes shining with hope and love.
#
# Lily was speechless, her mind racing with a whirlwind of emotions. After a moment of stunned silence, she nodded her head, a radiant smile spreading across her face.
#
# "Yes, Ethan. Yes, I'll marry you!"
#
# They embraced, tears of joy streaming down their faces, as they celebrated the beginning of a new chapter in their lives. The unexpected love story that had blossomed on a chance encounter had now grown into a lifelong commitment, a testament to the power of fate and the resilience of the human heart.
#
# As they walked hand in hand, Lily and Ethan knew that their journey together was just beginning, and they couldn't wait to see what the future held.
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: False

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
print(hints.exercise_2_3_hint)

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
